# %% [markdown]
# **Write a program to subtract two complex numbers**

# %%
a =2+3.9j
b =1-0.89j
c = a-b
print('Answer to the subtraction of a=',a,'and b=',b,' is c=',c)
# Out:
# Answer to the subtraction of a= (2+3.9j) and b= (1-0.89j)  is c= (1+4.79j)

# %% [markdown]
# write a program to find the fourth root of a number

# %%
num =90
print("fouth root of the number is ",num**1/4)
# Out:
# fouth root of the number is  22.5

# %% [markdown]
# **Write a program to swap two numbers in Python with the help of a temporary variable.**

# %%
x =25  #x before swap
y =41  #y before swap
temp =x
x=y
y=temp
print("numbers after swapping are x=",x," y=",y)
# Out:
# numbers after swapping are x= 41  y= 25

# %% [markdown]
# **Write a program to swap two numbers in Python without using a temporary variable.**

# %%
A1 =25   #A1 before swap
A2 =41   #A2 before swap
A1 =A1+A2
A2 =A1-A2
A1 =A1-A2
print("numbers after swapping are A1=",A1," A2=",A2)
# Out:
# numbers after swapping are A1= 41  A2= 25

# %% [markdown]
# **Write a program to convert fahrenheit to kelvin and celsius both.**

# %%
Temp_F =102
Temp_C =(Temp_F-32)*5/9
Temp_K =Temp_C+273.15
print("Temperature in Kelvin",Temp_K," and in celsius is ",Temp_C)
# Out:
# Temperature in Kelvin 312.0388888888889  and in celsius is  38.888888888888886

# %% [markdown]
# **Write a program to demonstrate all the available data types in Python.**

# %%
l = "Here are the listed data types"
m =1
n =1.5
o =105+25j
p =2,3,4
print("l is ",type(l))
print("m is ",type(m))
print("n is ",type(n))
print("o is ",type(o))
print("p is ",type(p))
# Out:
# l is  <class 'str'>
# m is  <class 'int'>
# n is  <class 'float'>
# o is  <class 'complex'>
# p is  <class 'tuple'>

# %% [markdown]
# **Create Github profile and upload Githubs Assignment link.**

# %% [markdown]
# sign up to github.com /n
# after successfully logging in create a repositories by click on + sign /n
# name repository as ** LetsUpgrade-AI-ML**(by default it is public) /n
# Add Folder of assignment And then open the file andcopy URL /n
# Senf the url in the assignment link.
