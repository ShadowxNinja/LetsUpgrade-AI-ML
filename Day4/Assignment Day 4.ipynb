# %% [markdown]
# **Question 1 :**
# Research on whether addition, subtraction, multiplication, division, floor division and modulo
# operations be performed on complex numbers. Based on your study, implement a Python
# program to demonstrate these operations.

# %% [markdown]
# >>>The modulus and floor division operations cannot be performed on complex numbers,rest all the above operations can be performed.

# %%
a =5+5j
b =2+2j

print("adition is ",a+b)
print("subtraction is ",a-b)
print("multipliction is ",a*b)
print("division is ",a/b)
print("a exponential b is ",a**b)
# Out:
# adition is  (7+7j)
# subtraction is  (3+3j)
# multipliction is  20j
# division is  (2.5+0j)
# a exponential b is  (7.238825517473248-7.458833741746015j)

# %% [markdown]
# **Question 2 :**
# Research on range() functions and its parameters. Create a markdown cell and write in your own
# words (no copy-paste from google please) what you understand about it. Implement a small
# program of your choice on the same.

# %% [markdown]
# >>> The range function is used for a specific set of sequence where in the syntax we need to define the start stop and step value.By defaut the values of start and step are 0,1 respectively.
# The range fuction can be used to list the numbers required to carry out further operations where in we need require to provide an input manually one by one.

# %%
r =range(2,20,2)
for i in r:
  print(i)
# Out:
# 2
# 4
# 6
# 8
# 10
# 12
# 14
# 16
# 18

# %% [markdown]
# **Question 3:**
#  Consider two numbers. Perform their subtraction and if the result of subtraction is greater than
# 25, print their multiplication result else print their division result.

# %%
x =50
y =2
z =x-y
if x-y > 25:
  print("RESULT Multiplication",x*y)
else:
  print("RESULT Division",x/y)
# Out:
# RESULT Multiplication 100

# %% [markdown]
# **Question 4:**
# Consider a list of 10 elements of integer values. If the number in the list is divisible by 2, print the
# result as "square of that number minus 2".

# %%
lst =[2,20,5,8,54,10,11,88,98,67]
for i in lst:
  if i%2 == 0:
    print(i**2-2)
# Out:
# 2
# 398
# 62
# 2914
# 98
# 7742
# 9602

# %% [markdown]
# **Question 5:**
# Consider a list of 10 elements. Print all the elements in the list which are greater than 7 when that
# number is divided 2

# %%
l =[10,55,48,89,74,2,5,652,454,25]
for i in l:
  if i/2 >7:
    print(i)
# Out:
# 55
# 48
# 89
# 74
# 652
# 454
# 25
